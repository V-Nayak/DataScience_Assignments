# %% [markdown]
# <a href="https://colab.research.google.com/github/V-Nayak/DataScience_Assignments/blob/main/03_Assi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("hello World")
#python prgram to swap two veriables
x=5
y=10
#Create a temp veriable and swap the values
temp=x
x=y
y=temp
print (x)
print (y)
# Out:
# hello World
# 10
# 5

# %% [markdown]
# ![Screenshot (2).png](data:image/png;base64,...)

# %% [markdown]
# ## Image of comparing the 2 programs in Notepad++

# %% [markdown]
# ![Screenshot (4).png](data:image/png;base64,...)

# %% [markdown]
# ![GIt install_file creation.png](data:image/png;base64,...)
