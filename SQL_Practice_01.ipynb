# %% [markdown]
# <a href="https://colab.research.google.com/github/V-Nayak/DataScience_Assignments/blob/main/SQL_Practice_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **DAy 1**

# %% [markdown]
# ![Screenshot (27).png](data:image/png;base64,...)
